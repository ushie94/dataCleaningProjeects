# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import scipy as spy

# %%
df = pd.read_table(r"C:\DATA ANALYSIS\EXCEL\ImportText1.txt")

# %%
df.set_index('Employee Name')
# Out:
#                     Hire Date   Salary    Department             Job Title
# Employee Name
# Jose Juarez         12/3/2008  $39,000         Admin                Intern
# Johnny Abraham      3/30/2013  $27,000   Engineering               Trainee
# Sarah Baker         4/30/2015  $36,000         Sales       Sales Executive
# Billy Balotelli    11/15/2007  $23,900   Engineering                Intern
# Tiana Bishop         6/6/2003  $46,500   Engineering               Manager
# Terryy Boateng      7/27/2009  $50,000      Accounts       Cost Accountant
# Fred Boer          12/23/2010  $46,000          Mktg              Designer
# Betty Barker        7/25/2007  $43,500         Sales       Sales Executive
# Tom Bursteyn       10/11/2009  $21,000         Sales         Sales Trainee
# Tammy Jones        10/12/2009  $38,000         Sales       Sales Executive
# Bobby Busser         8/8/2014  $40,000      Accounts  Senior Administrator
# ...
