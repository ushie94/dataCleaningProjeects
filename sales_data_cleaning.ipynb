# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\DATA ANALYSIS\EXCEL\DIRTY_DATASETS\supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
specific_Branch = ['A', 'B']

df[df['Branch'].isin(specific_Branch)]
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    750-67-8428      A    Yangon        Member  Female
# 2    631-41-3108      A    Yangon        Normal    Male
# 3    123-19-1176      A    Yangon        Member    Male
# 4    373-73-7910      A    Yangon        Normal    Male
# 6    355-53-5943      A    Yangon        Member  Female
# ..           ...    ...       ...           ...     ...
# 993  690-01-6631      B  Mandalay        Normal    Male
# 996  303-96-2227      B  Mandalay        Normal  Female
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# ...

# %%
df2 = df.set_index("Customer type")
df2
# Out:
#                 Invoice ID Branch       City  Gender            Product line  \
# Customer type
# Member         750-67-8428      A     Yangon  Female       Health and beauty
# Normal         226-31-3081      C  Naypyitaw  Female  Electronic accessories
# Normal         631-41-3108      A     Yangon    Male      Home and lifestyle
# Member         123-19-1176      A     Yangon    Male       Health and beauty
# Normal         373-73-7910      A     Yangon    Male       Sports and travel
# ...                    ...    ...        ...     ...                     ...
# Normal         233-67-5758      C  Naypyitaw    Male       Health and beauty
# Normal         303-96-2227      B   Mandalay  Female      Home and lifestyle
# Member         727-02-1313      A     Yangon    Male      Food and beverages
# Normal         347-56-2442      A     Yangon    Male      Home and lifestyle
# Member         849-09-3807      A     Yangon  Female     Fashion accessories
#
# ...

# %%
df2.filter(items = ['Member', 'Gender'], axis=1)
# Out:
#                Gender
# Customer type
# Member         Female
# Normal         Female
# Normal           Male
# Member           Male
# Normal           Male
# ...               ...
# Normal           Male
# Normal         Female
# Member           Male
# Normal           Male
# Member         Female
#
# [1000 rows x 1 columns]

# %%
df2.loc['Normal']
# Out:
#                 Invoice ID Branch       City  Gender            Product line  \
# Customer type
# Normal         226-31-3081      C  Naypyitaw  Female  Electronic accessories
# Normal         631-41-3108      A     Yangon    Male      Home and lifestyle
# Normal         373-73-7910      A     Yangon    Male       Sports and travel
# Normal         699-14-3026      C  Naypyitaw    Male  Electronic accessories
# Normal         315-22-5665      C  Naypyitaw  Female      Home and lifestyle
# ...                    ...    ...        ...     ...                     ...
# Normal         745-74-0715      A     Yangon    Male  Electronic accessories
# Normal         690-01-6631      B   Mandalay    Male     Fashion accessories
# Normal         233-67-5758      C  Naypyitaw    Male       Health and beauty
# Normal         303-96-2227      B   Mandalay  Female      Home and lifestyle
# Normal         347-56-2442      A     Yangon    Male      Home and lifestyle
#
# ...

# %%
df
df[df['Rating'] < 8.0].sort_values(by='City', ascending=False)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    631-41-3108      A    Yangon        Normal    Male
# 476  485-30-8700      A    Yangon        Normal  Female
# 525  719-89-8991      A    Yangon        Member  Female
# 522  609-81-8548      A    Yangon        Member  Female
# 513  189-52-0236      A    Yangon        Normal    Male
# ..           ...    ...       ...           ...     ...
# 612  789-23-8625      B  Mandalay        Member    Male
# 129  549-84-7482      B  Mandalay        Normal  Female
# 130  191-10-6171      B  Mandalay        Normal  Female
# 603  642-30-6693      B  Mandalay        Normal  Female
# 507  862-17-9201      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 476       Sports and travel       33.26         5   8.3150  174.6150
# 525       Sports and travel       91.41         5  22.8525  479.9025
# ...

# %%
df2.iloc[476]
# Out:
# Invoice ID                       485-30-8700
# Branch                                     A
# City                                  Yangon
# Gender                                Female
# Product line               Sports and travel
# Unit price                             33.26
# Quantity                                   5
# Tax 5%                                 8.315
# Total                                174.615
# Date                               3/18/2019
# Time                                   16:10
# Payment                          Credit card
# cogs                                   166.3
# gross margin percentage             4.761905
# gross income                           8.315
# Rating                                   4.2
# Name: Normal, dtype: object

# %%
group_by_frame = df2.groupby('Product line')

# %%
group_by_frame.mean('Product line')
# Out:
#                         Unit price  Quantity     Tax 5%       Total  \
# Product line
